# %% [markdown]
# # Demo notebook
#
# This is a **markdown** cell. It opens *rendered*. Press `i` (or `Enter`) to edit the
# source, and `e` (or `Ctrl+Enter`) to render it again.
#
# - bullet one
# - bullet two with `inline code`
#
# > A blockquote, and a [link](https://example.com).

# %%
x = 21

x * 2
# Out:
# 42

# %%
import sympy
from time import sleep
sleep(3)
sympy.sqrt(8)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow(np.random.randn(100,100))
plt.show()
